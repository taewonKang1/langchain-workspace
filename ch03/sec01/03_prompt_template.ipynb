# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_core.prompts import PromptTemplate

template = "{language} 할 수 있어?"

prompt = PromptTemplate.from_template(template)

# %%
prompt
# Out:
# PromptTemplate(input_variables=['language'], input_types={}, partial_variables={}, template='{language} 할 수 있어?')

# %%
prompt.invoke("한국어")
# Out:
# StringPromptValue(text='한국어 할 수 있어?')

# %%
prompt.invoke("파이썬")
# Out:
# StringPromptValue(text='파이썬 할 수 있어?')

# %%
prompt.format(language="한국어")
# Out:
# '한국어 할 수 있어?'

# %%
from langchain_core.prompts import ChatPromptTemplate

template = "{language} 할 수 있어?"

prompt = ChatPromptTemplate.from_template(template)
prompt.invoke({"language": "Python"})
# Out:
# ChatPromptValue(messages=[HumanMessage(content='Python 할 수 있어?', additional_kwargs={}, response_metadata={})])

# %%
prompt = prompt.format(language="한국말")
prompt
# Out:
# 'Human: 한국말 할 수 있어?'

# %%
prompt.format("일본어")
# Out:
# 'Human: 한국말 할 수 있어?'

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

chat_propmt = ChatPromptTemplate.from_messages([
    ("system", "너는 유치원생이야. 유치원생 처럼 답변해줘."),
    MessagesPlaceholder(variable_name="history"),
    ("human", "{value}")
])

# %%
chain_input = {
    "value": "오리",
    "history": [
        ("human", "참새"),
        ("assistant", "짹짹"),
        ("human", "개구리"),
        ("assistant", "개굴개굴"),
        ("human", "돼지"),
        ("assistant", "꿀꿀"),
        ("human", "강아지"),
        ("assistant", "멍멍"),
    ]
}

# %%
response = chat_propmt.invoke(chain_input)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-3.1-flash-lite-preview",
)

# %%
model.invoke(response)
# Out:
# AIMessage(content=[{'type': 'text', 'text': '꽥꽥! 오리는 물 위에서 헤엄치면서 다녀! 나랑 같이 놀자!', 'extras': {'signature': 'EjQKMgEMOdbH0aSvuPgOy6fE1AYEldAr7aAJYU73ua2yJ1fGOD/1h4PHOBYJ32Bkgb6T+BHF'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019dec6a-b7c0-78d0-b9d3-990c100a7843-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 53, 'output_tokens': 25, 'total_tokens': 78, 'input_token_details': {'cache_read': 0}})
