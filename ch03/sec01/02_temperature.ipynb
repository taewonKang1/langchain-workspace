# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-3.1-flash-lite-preview",
    temperature=0,
)

# %%
prompt = """당신은 LangChain 개발자입니다. 새로운 에이전트(Agent)를 구축하는 과정을 담은 매우 짧은 기술 동화 또는 비유적인 이야기를 작성하시오.
1. 이야기는 반드시 120자 이상 250자 이하의 한글로 구성되어야 합니다.
2. 이야기에 'Chain', 'PromptTemplate', 'Memory' 세 단어를 반드시 포함해야 합니다.
3. 이야기의 결말은 구축한 에이전트가 현실 세계에서 **예상치 못한** 문제 해결에 성공하는 장면으로 마무리되어야 합니다."""

# %%
ai_msg = model.invoke(prompt)
ai_msg
# Out:
# AIMessage(content=[{'type': 'text', 'text': '어느 날, 꼬마 개발자는 똑똑한 에이전트를 만들기로 했습니다. 먼저 **PromptTemplate**으로 지식의 틀을 잡고, **Memory**를 심어 과거의 대화를 기억하게 했죠. 마지막으로 여러 도구를 엮는 **Chain**을 연결하자 에이전트가 눈을 떴습니다. 어느 날, 에이전트는 서버 오류가 아닌, 길 잃은 고양이의 울음소리 주파수를 분석해 주인의 집 위치를 정확히 찾아내어 모두를 놀라게 했습니다.', 'extras': {'signature': 'EjQKMgEMOdbHcYAjA02WJO1lY5orKqdWhxPnCBPET/9qnF500KTs6MRrLTrbVhLMrFk8JxOV'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019dec41-7a67-7821-96b4-645714c692c8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 124, 'output_tokens': 119, 'total_tokens': 243, 'input_token_details': {'cache_read': 0}})

# %%
ai_msg.content[0].get("text")
# Out:
# '어느 날, 꼬마 개발자는 똑똑한 에이전트를 만들기로 했습니다. 먼저 **PromptTemplate**으로 지식의 틀을 잡고, **Memory**를 심어 과거의 대화를 기억하게 했죠. 마지막으로 여러 도구를 엮는 **Chain**을 연결하자 에이전트가 눈을 떴습니다. 어느 날, 에이전트는 서버 오류가 아닌, 길 잃은 고양이의 울음소리 주파수를 분석해 주인의 집 위치를 정확히 찾아내어 모두를 놀라게 했습니다.'

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-3.1-flash-lite-preview",
    temperature=2,
)

# %%
ai_msg = model.invoke(prompt)
ai_msg
# Out:
# AIMessage(content=[{'type': 'text', 'text': "새로운 에이전트 '라온'을 만들었습니다. 먼저 도구 사용법을 정할 'PromptTemplate'을 다듬고, 과거의 경험을 기록할 'Memory'를 심었죠. 이후 각 작업을 잇는 'Chain'을 연결하자 라온은 스스로 생각하기 시작했습니다. 며칠 뒤, 예상치 못한 서버 오류가 발생했을 때 라온은 모든 기록을 스스로 되짚어 본 뒤, 프로그래머조차 간과했던 낡은 설정 파일을 수정해 서비스 중단을 단숨에 해결해냈습니다.", 'extras': {'signature': 'EjQKMgEMOdbHPNvh8+J3lksl22ByCLiSHCVw/FrhQcBn0wMfspBj6ohEsce/Ns6RaJGyIUc3'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019dec43-1942-78c0-a1ff-ed66c00dffeb-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 124, 'output_tokens': 119, 'total_tokens': 243, 'input_token_details': {'cache_read': 0}})

# %%
ai_msg.content[0].get("text")
# Out:
# "새로운 에이전트 '라온'을 만들었습니다. 먼저 도구 사용법을 정할 'PromptTemplate'을 다듬고, 과거의 경험을 기록할 'Memory'를 심었죠. 이후 각 작업을 잇는 'Chain'을 연결하자 라온은 스스로 생각하기 시작했습니다. 며칠 뒤, 예상치 못한 서버 오류가 발생했을 때 라온은 모든 기록을 스스로 되짚어 본 뒤, 프로그래머조차 간과했던 낡은 설정 파일을 수정해 서비스 중단을 단숨에 해결해냈습니다."
